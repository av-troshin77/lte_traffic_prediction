# %% [markdown]
# # Plotting

# %% [markdown]
# ## 1. Load the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('dataset.csv', index_col='Timestamp')
df.head()
# Out:
#                      Cell_000111  Cell_000112  Cell_000113  Cell_000231  \
# Timestamp
# 2017-10-23 00:00:00     29.26490     59.15291     59.01721      2.63658
# 2017-10-23 01:00:00     19.26170     60.22876     40.34814     13.16293
# 2017-10-23 02:00:00     18.37236     14.83900      1.27435     25.36683
# 2017-10-23 03:00:00     18.69268      0.98166      2.11746      1.66842
# 2017-10-23 04:00:00     21.62559      4.28219      3.51484      1.78151
#
#                      Cell_000232  Cell_000233  Cell_000461  Cell_000462  \
# Timestamp
# 2017-10-23 00:00:00     14.11635      3.37565      7.69811      0.62042
# 2017-10-23 01:00:00      0.96246      7.47019     31.07216      0.52249
# 2017-10-23 02:00:00      1.07481      3.88256     26.14190      1.10567
# 2017-10-23 03:00:00      0.85055     14.04557      0.56444      0.50090
# 2017-10-23 04:00:00      0.71691     12.94846     27.45815     17.99582
#
# ...

# %% [markdown]
# ## 2. Replace NaN

# %%
df.isna().sum().sum()
# Out:
# 522

# %%
# new_df = df.interpolate(method='linear', axis=1) # linear interpolate
new_df = df.fillna(method='ffill', axis=1) # forward the last valid observation
new_df = df.fillna(0) # fill with 0s
new_df.isna().sum().sum()
# Out:
# 0

# %%
df = new_df

# %% [markdown]
# ## 2. Plot Cell Traffic

# %%
# day traffic
cellname = "Cell_000231"
ax = df.loc['2018-06-11':'2018-06-12', cellname].plot(figsize=(11,9),
                                                      x_compat=True,
                                                      grid=True,
                                                      linewidth=2)
ax.set_title(cellname)
ax.set_xlabel('Время')
ax.set_ylabel('Траффик, Мбит/с')
# save to a file
filename = cellname + '_day.png'
plt.savefig(filename)
plt.show()

# %%
# week traffic
cellname = "Cell_000231"
ax = df.loc['2018-06-11':'2018-06-18', cellname].plot(figsize=(11,9),
                                                      x_compat=True,
                                                      grid=True,
                                                      linewidth=2,
                                                      rot=30)
ax.set_title(cellname)
ax.set_xlabel('Время')
ax.set_ylabel('Траффик, Мбит/с')
# save to a file
filename = cellname + '_week.png'
plt.savefig(filename)
plt.show()

# %%
# week end traffic
cellname = "Cell_000231"
ax = df.loc['2018-06-17':'2018-06-18', cellname].plot(figsize=(11,9),
                                                      x_compat=True,
                                                      grid=True,
                                                      linewidth=2,
                                                      rot=0)
ax.set_title(cellname)
ax.set_xlabel('Время')
ax.set_ylabel('Траффик, Мбит/с')
# save to a file
filename = cellname + '_weekend.png'
plt.savefig(filename)
plt.show()
